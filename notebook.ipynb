# %% [markdown]
# <h1 align=center>CP1 Data Science - EDA</h1>
# <p align=center>Eduardo Ulisses</p>
# <p align=center>Henrique Guedes</p>
# <p align=center>2ESPV</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


data = pd.read_csv("data/raw/ai_company_adoption.csv")
df = data.copy()

print(
    """
        =================================
        Preparação e Qualidade dos dados
        =================================
    """

)

# Visualização inicial
print("=== HEAD ===")
print(df.head(8))

print("\n=== INFO ===")
df.info()

print("\n=== % DE NULOS POR COLUNA ===")
print(df.isnull().mean() * 100)

# Regras de limpeza
print("\n=== DUPLICATAS ===")
print(f"Linhas duplicadas: {df.duplicated().sum()}")
df.drop_duplicates(inplace=True)

print("\n=== REMOVENDO COLUNAS IRRELEVANTES ===")
colunas_relevantes = [
    'survey_year',
    'country',
    'industry',
    'company_size',
    'num_employees',
    'annual_revenue_usd_millions',
    'ai_adoption_rate',
    'ai_maturity_score',
    'years_using_ai',
    'ai_budget_percentage',
    'productivity_change_percent',
    'task_automation_rate',
    'time_saved_per_week',
    'jobs_displaced',
    'jobs_created',
    'reskilled_employees',
    'revenue_growth_percent',
    'cost_reduction_percent',
    'employee_satisfaction_score',
    'customer_satisfaction'
]
df = df[colunas_relevantes]
print(f"Colunas restantes: {df.shape[1]}\n")
print(df.info())

print("\n=== DATASET FINAL ===")
print(df.shape)

print("\n=== CRIANDO NOVO ARQUIVO CSV ===")
df.to_csv("./data/processed/dataset_clean.csv", index=False)
print("\nNovo arquivo criado em /data/processed/")



data = pd.read_csv("data/processed/dataset_clean.csv")

df = data[['ai_adoption_rate', 'productivity_change_percent']].copy()

print(
    """
    ==========================================
    Estatística descritiva “com interpretação”
    ==========================================
    """
)

print(
    """
    ======================================================================
         Histogramas: Ai Adoption Rate X Productivity Change Percent
    ======================================================================
    """
)
print(df.head(8))
print("\n")
print("\nMédia:\n", df.mean())
print("\nMediana:\n", df.median())
print("\nModa:\n", df.mode())
print("\nVariância Amostral:\n", df.var(ddof=1))
print("\nDP amostral:\n", df.std(ddof=1))




fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Ai Adoption Rate Graphics
axes[0].hist(df['ai_adoption_rate'], bins="auto", color="steelblue", alpha=0.7)
axes[0].set_title("Histograma: AI Adoption Rate")
axes[0].set_xlabel("%")
axes[0].set_ylabel("Frequência")

# Productivity Change Percent Graphics
axes[1].hist(df['productivity_change_percent'], bins="auto", color="orange", alpha=0.7)
axes[1].set_title("Histograma: Productivity Change")
axes[1].set_xlabel("%")
axes[1].set_ylabel("Frequência")

plt.tight_layout()
plt.show()


print(
    """
    ==========================================
         Correlação entre as variáveis
    ==========================================
    """
)

correlacao = df['ai_adoption_rate'].corr(df['productivity_change_percent'])
corr2 = data['task_automation_rate'].corr(data['time_saved_per_week'])

print("Correlações de Pearson\n")
print(f"Correlação entre adoção de ia e aumento na produtividade: {correlacao:.3f}")
print(f"Correlação entre automação e tempo economizado: {corr2:.3f}")

fig, axes2 = plt.subplots(1, 2, figsize=(12,4))

# Scatter 1
axes2[0].scatter(
    df['ai_adoption_rate'],
    df['productivity_change_percent'],
    alpha=0.7,
    color="purple"
)
axes2[0].set_title("AI Adoption Rate vs Productivity Change")
axes2[0].set_xlabel("AI Adoption Rate (%)")
axes2[0].set_ylabel("Productivity Change (%)")
axes2[0].grid(True)

# Scatter 2
axes2[1].scatter(
    data['task_automation_rate'],
    data['time_saved_per_week'],
    color="green",
    alpha=0.7
)
axes2[1].set_title("Task Automation Rate vs Time Saved per Week")
axes2[1].set_xlabel("Task Automation Rate (%)")
axes2[1].set_ylabel("Time Saved per Week (hours)")
axes2[1].grid(True)

plt.tight_layout()
plt.show()

print(
        """
            ==========================
            Outliers com IQR e Boxplot
            ==========================\n
        """
)

df = data.copy()

target = "annual_revenue_usd_millions"

def iqr_outliers(series):
    s = series.dropna()
    q1 = s.quantile(0.25)
    q3 = s.quantile(0.75)
    iqr = q3 - q1
    low = q1 - 1.5 * iqr
    high = q3 + 1.5 * iqr
    mask = (series < low) | (series > high)
    return mask, low, high


mask, low, high = iqr_outliers(df[target])
print(f"{target}: total de outliers = {mask.sum()} | limites=[{low:.3f}, {high:.3f}]")

df_raw = df[target].dropna()
df_clean = df.loc[~mask, target].dropna()

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

axes[0].boxplot(df_raw.values, vert=True)
axes[0].set_title(f"ANTES")
axes[0].set_ylabel(target)

axes[1].boxplot(df_clean.values, vert=True)
axes[1].set_title(f"DEPOIS")
axes[1].set_ylabel(target)

plt.suptitle(f"Remoção de outliers via IQR - {target}")
plt.tight_layout()
plt.show()
# Out:
#         =================================
#         Preparação e Qualidade dos dados
#         =================================
#
# === HEAD ===
#    response_id  company_id  survey_year quarter country  region   industry  \
# 0            1  COMP-00001         2023      Q1   Italy  Europe  Education
# 1            2  COMP-00001         2023      Q2   Italy  Europe  Education
# 2            3  COMP-00001         2023      Q3   Italy  Europe  Education
# 3            4  COMP-00001         2023      Q4   Italy  Europe  Education
# 4            5  COMP-00001         2024      Q1   Italy  Europe  Education
# 5            6  COMP-00001         2024      Q2   Italy  Europe  Education
# 6            7  COMP-00001         2024      Q3   Italy  Europe  Education
# 7            8  COMP-00001         2024      Q4   Italy  Europe  Education
#
#   company_size  num_employees  annual_revenue_usd_millions  ...  \
# 0      Startup             57                        48.31  ...
# 1      Startup             57                        48.31  ...
# 2      Startup             57                        48.31  ...
# 3      Startup             57                        48.31  ...
# 4      Startup             57                        48.31  ...
# 5      Startup             57                        48.31  ...
# 6      Startup             57                        48.31  ...
# 7      Startup             57                        48.31  ...
#
#    productivity_change_percent  jobs_displaced jobs_created  \
# 0                         2.65               1            1
# 1                         5.77               2            2
# 2                         6.94               3            3
# 3                         5.32               1            1
# 4                         6.32               2            3
# 5                        17.83               4            2
# 6                        12.33               5            3
# 7                         5.72               2            4
#
#    reskilled_employees revenue_growth_percent  cost_reduction_percent  \
# 0                    3                   2.52                    9.45
# 1                    5                   4.77                    0.00
# 2                    2                  12.87                    9.74
# 3                    2                   8.19                    0.00
# 4                    6                  11.30                    9.02
# 5                    3                   9.57                    1.90
# 6                    6                  11.29                    5.15
# 7                    5                  10.72                    3.95
#
#   innovation_score  customer_satisfaction              survey_source  \
# 0               53                   5.20                 WEF Survey
# 1               51                   6.98            McKinsey Report
# 2               40                   4.12  Internal Corporate Survey
# 3               51                   5.72  Internal Corporate Survey
# 4               43                   6.31            McKinsey Report
# 5               53                   5.12            McKinsey Report
# 6               69                   6.17                 WEF Survey
# 7               64                   3.55  Internal Corporate Survey
#
#    data_collection_method
# 0              API Scrape
# 1         Phone Interview
# 2    Research Compilation
# 3    Research Compilation
# 4    Research Compilation
# 5              API Scrape
# 6         Phone Interview
# 7              API Scrape
#
# [8 rows x 43 columns]
#
# === INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   response_id                  150000 non-null  int64
#  1   company_id                   150000 non-null  object
#  2   survey_year                  150000 non-null  int64
#  3   quarter                      150000 non-null  object
#  4   country                      150000 non-null  object
#  5   region                       150000 non-null  object
#  6   industry                     150000 non-null  object
#  7   company_size                 150000 non-null  object
#  8   num_employees                150000 non-null  int64
#  9   annual_revenue_usd_millions  150000 non-null  float64
#  10  company_founding_year        150000 non-null  int64
#  11  company_age                  150000 non-null  int64
#  12  company_age_group            150000 non-null  object
#  13  ai_adoption_rate             150000 non-null  float64
#  14  ai_adoption_stage            150000 non-null  object
#  15  years_using_ai               150000 non-null  int64
#  16  ai_primary_tool              150000 non-null  object
#  17  num_ai_tools_used            150000 non-null  int64
#  18  ai_use_case                  150000 non-null  object
#  19  ai_projects_active           150000 non-null  int64
#  20  ai_training_hours            150000 non-null  float64
#  21  ai_budget_percentage         150000 non-null  float64
#  22  ai_maturity_score            150000 non-null  float64
#  23  ai_failure_rate              150000 non-null  float64
#  24  ai_investment_per_employee   150000 non-null  float64
#  25  regulatory_compliance_score  150000 non-null  int64
#  26  data_privacy_level           150000 non-null  object
#  27  ai_ethics_committee          150000 non-null  object
#  28  ai_risk_management_score     150000 non-null  int64
#  29  remote_work_percentage       150000 non-null  float64
#  30  employee_satisfaction_score  150000 non-null  float64
#  31  task_automation_rate         150000 non-null  float64
#  32  time_saved_per_week          150000 non-null  float64
#  33  productivity_change_percent  150000 non-null  float64
#  34  jobs_displaced               150000 non-null  int64
#  35  jobs_created                 150000 non-null  int64
#  36  reskilled_employees          150000 non-null  int64
#  37  revenue_growth_percent       150000 non-null  float64
#  38  cost_reduction_percent       150000 non-null  float64
#  39  innovation_score             150000 non-null  int64
#  40  customer_satisfaction        150000 non-null  float64
#  41  survey_source                150000 non-null  object
#  42  data_collection_method       150000 non-null  object
# dtypes: float64(15), int64(14), object(14)
# memory usage: 49.2+ MB
#
# === % DE NULOS POR COLUNA ===
# response_id                    0.0
# company_id                     0.0
# survey_year                    0.0
# quarter                        0.0
# country                        0.0
# region                         0.0
# industry                       0.0
# company_size                   0.0
# num_employees                  0.0
# annual_revenue_usd_millions    0.0
# company_founding_year          0.0
# company_age                    0.0
# company_age_group              0.0
# ai_adoption_rate               0.0
# ai_adoption_stage              0.0
# years_using_ai                 0.0
# ai_primary_tool                0.0
# num_ai_tools_used              0.0
# ai_use_case                    0.0
# ai_projects_active             0.0
# ai_training_hours              0.0
# ai_budget_percentage           0.0
# ai_maturity_score              0.0
# ai_failure_rate                0.0
# ai_investment_per_employee     0.0
# regulatory_compliance_score    0.0
# data_privacy_level             0.0
# ai_ethics_committee            0.0
# ai_risk_management_score       0.0
# remote_work_percentage         0.0
# employee_satisfaction_score    0.0
# task_automation_rate           0.0
# time_saved_per_week            0.0
# productivity_change_percent    0.0
# jobs_displaced                 0.0
# jobs_created                   0.0
# reskilled_employees            0.0
# revenue_growth_percent         0.0
# cost_reduction_percent         0.0
# innovation_score               0.0
# customer_satisfaction          0.0
# survey_source                  0.0
# data_collection_method         0.0
# dtype: float64
#
# === DUPLICATAS ===
# Linhas duplicadas: 0
#
# === REMOVENDO COLUNAS IRRELEVANTES ===
# Colunas restantes: 20
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   survey_year                  150000 non-null  int64
#  1   country                      150000 non-null  object
#  2   industry                     150000 non-null  object
#  3   company_size                 150000 non-null  object
#  4   num_employees                150000 non-null  int64
#  5   annual_revenue_usd_millions  150000 non-null  float64
#  6   ai_adoption_rate             150000 non-null  float64
#  7   ai_maturity_score            150000 non-null  float64
#  8   years_using_ai               150000 non-null  int64
#  9   ai_budget_percentage         150000 non-null  float64
#  10  productivity_change_percent  150000 non-null  float64
#  11  task_automation_rate         150000 non-null  float64
#  12  time_saved_per_week          150000 non-null  float64
#  13  jobs_displaced               150000 non-null  int64
#  14  jobs_created                 150000 non-null  int64
#  15  reskilled_employees          150000 non-null  int64
#  16  revenue_growth_percent       150000 non-null  float64
#  17  cost_reduction_percent       150000 non-null  float64
#  18  employee_satisfaction_score  150000 non-null  float64
#  19  customer_satisfaction        150000 non-null  float64
# dtypes: float64(11), int64(6), object(3)
# memory usage: 22.9+ MB
# None
#
# === DATASET FINAL ===
# (150000, 20)
#
# === CRIANDO NOVO ARQUIVO CSV ===
#
# Novo arquivo criado em /data/processed/
#
#     ==========================================
#     Estatística descritiva “com interpretação”
#     ==========================================
#
#
#     ======================================================================
#          Histogramas: Ai Adoption Rate X Productivity Change Percent
#     ======================================================================
#
#    ai_adoption_rate  productivity_change_percent
# 0             30.57                         2.65
# 1             27.25                         5.77
# 2             31.54                         6.94
# 3             11.02                         5.32
# 4             33.39                         6.32
# 5             34.15                        17.83
# 6             41.35                        12.33
# 7             57.42                         5.72
#
#
#
# Média:
#  ai_adoption_rate               36.414726
# productivity_change_percent     9.266996
# dtype: float64
#
# Mediana:
#  ai_adoption_rate               36.32
# productivity_change_percent     9.06
# dtype: float64
#
# Moda:
#     ai_adoption_rate  productivity_change_percent
# 0               0.0                          0.0
#
# Variância Amostral:
#  ai_adoption_rate               211.530739
# productivity_change_percent     31.776522
# dtype: float64
#
# DP amostral:
#  ai_adoption_rate               14.544096
# productivity_change_percent     5.637067
# dtype: float64
#     ==========================================
#          Correlação entre as variáveis
#     ==========================================
#
# Correlações de Pearson
#
# Correlação entre adoção de ia e aumento na produtividade: 0.675
# Correlação entre automação e tempo economizado: 0.793
#             ==========================
#             Outliers com IQR e Boxplot
#             ==========================
#
#
# annual_revenue_usd_millions: total de outliers = 27947 | limites=[-581.525, 1059.555]
